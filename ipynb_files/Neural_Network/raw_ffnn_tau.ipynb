# %%
import ast
def extract_L_set(filepath):
    l_set = []
    capture = False
    with open(filepath, 'r') as file:
        for line in file:
            line = line.strip()
        
            # Start capturing when we see the header
            if line.startswith("L set:"):
                capture = True
                continue
        
            # Stop capturing when we reach the B vector
            if line.startswith("B vector:"):
                capture = False
                break
            
            # If we are in the capture zone and the line looks like a list
            if capture and line.startswith("["):
                # ast.literal_eval safely converts the string "[1, 2...]" into a Python list
                row = ast.literal_eval(line)
                l_set.append(row)
    return l_set

# %%
import numpy as np

# ===========================
# Complete dataset
# ===========================

train_filePath = '../ED_Calculation/2003_2023/results/finalize_L_set_from_2003_to_2023.txt'
train_data= np.array(extract_L_set(train_filePath))
test_filepath = "../ED_Calculation/2024_current/results/final_result_df_2024_2025.txt"
test_data = np.array(extract_L_set(test_filepath))

X_full = train_data[:, :5]
y_full = train_data[:, 5]

X_test = test_data[:, :5]
y_test = test_data[:, 5]

y_full_bin = (y_full > 0).astype(int).reshape(-1, 1)
y_test_bin = (y_test > 0).astype(int).reshape(-1, 1)

split_idx = int(0.8 * len(X_full))
X_train = X_full[:split_idx]
y_train = y_full_bin[:split_idx]
X_val   = X_full[split_idx:]
y_val   = y_full_bin[split_idx:]

mean = X_train.mean(axis=0)
std  = X_train.std(axis=0)
X_train_n = (X_train - mean) / std
X_val_n   = (X_val   - mean) / std
X_test_n  = (X_test  - mean) / std

# %%
# ------------- Network (16 hidden) -------------
input_size  = 5
hidden_size = 16
output_size = 1
tau = 1.4

np.random.seed(0)
W_h = np.random.randn(input_size, hidden_size) * np.sqrt(2.0 / input_size)
W_o = np.random.randn(hidden_size, output_size) * np.sqrt(2.0 / hidden_size)
b_o = np.zeros((1, output_size))
B_h = np.random.randn(1, hidden_size) * 0.01   # small random biases
print(f"\n Hidden weight=> {W_h}")
print(f"\n Output weight=> {W_o}")

def hidden_sigmoid(x):
    return 1.0 / (1.0 + np.exp( -x * tau ))

def forward(X):
    H = hidden_sigmoid(X @ W_h + B_h)
    logits = H @ W_o + b_o       # linear output
    return H, logits

def binary_cross_entropy_with_logits(logits, y_true):
    max_logit = np.clip(logits, -100, 100)
    return np.mean(np.maximum(max_logit, 0) - max_logit * y_true + np.log(1 + np.exp(-np.abs(max_logit))))
# Out:
#  Hidden weight=> [[ 1.11568467  0.25308164  0.61900825  1.4172653   1.18114738 -0.6180848
#    0.60088868 -0.0957267  -0.06528133  0.25968529  0.09110115  0.91976332
#    0.48132252  0.07695404  0.28072376  0.21103417]
#  [ 0.94493858 -0.12975348  0.1980014  -0.54017758 -1.61465253  0.4133847
#    0.54671746 -0.46938637  1.43551887 -0.91982162  0.02894023 -0.11838546
#    0.96941469  0.92930408  0.09799736  0.23917098]
#  [-0.56148501 -1.25276568 -0.22003896  0.09888377  0.77810415  0.76045179
#   -0.24496699 -0.19119305 -0.66316312 -0.8980982  -1.07914002  1.23377869
#   -0.32233234 -0.27706252 -0.79233736  0.49172808]
#  [-1.02071862 -0.13454877 -0.56634278  0.24469863 -0.32306154 -0.74669736
#   -0.01782401  0.27090086  0.04206919  0.19130003 -0.40118052 -0.22941766
#   -0.42530133 -0.22740139 -0.51427886 -1.09179698]
#  [ 0.11221415 -0.25410858 -1.03102796  0.2926892  -0.57382587  0.03285315
#    0.46111736  0.08157596  0.72062027 -0.78097242  0.2544632  -0.43311193
#   -0.55074047 -0.36609667 -0.19704312  0.03552208]]
#
#  Output weight=> [[-0.41194268]
#  [ 0.31849026]
#  [ 0.16463653]
#  [-0.54314416]
#  [ 0.52617661]
#  [ 0.67029805]
#  [ 0.41676151]
#  [-0.06361304]
#  [-0.37856822]
#  [ 0.37280498]
#  [-0.14254458]
#  [ 0.4321996 ]
#  [ 0.07363632]
#  [ 0.34529404]
#  [ 0.12599455]
#  [ 0.24981134]]

# %%
# ------------- Training -------------
learning_rate = 0.052
epochs = 250
patience = 5
best_val_loss = np.inf
patience_counter = 0
epoch_log = []

for epoch in range(epochs):
    H, logits = forward(X_train_n)
    loss = binary_cross_entropy_with_logits(logits, y_train)

    p = 1.0 / (1.0 + np.exp(-logits))   # logistic sigmoid
    d_logits = (p - y_train) / X_train_n.shape[0]

    dW_o = H.T @ d_logits
    db_o = np.sum(d_logits, axis=0, keepdims=True)

    dH = d_logits @ W_o.T
    dZ_h = dH * (tau * H * (1 - H))

    dW_h = X_train_n.T @ dZ_h
    dB_h = np.sum(dZ_h, axis=0, keepdims=True)

    W_o -= learning_rate * dW_o
    b_o -= learning_rate * db_o
    W_h -= learning_rate * dW_h
    B_h -= learning_rate * dB_h

    _, val_logits = forward(X_val_n)
    val_loss = binary_cross_entropy_with_logits(val_logits, y_val)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    # Training accuracy
    train_pred = (logits > 0).astype(int)
    train_acc = np.mean(train_pred == y_train)
    val_pred = (val_logits > 0).astype(int)
    val_acc = np.mean(val_pred == y_val)
    epoch_log.append((epoch+1, loss, val_loss, train_acc, val_acc))
    print(f"Epoch {epoch+1:5d}/{epochs} ______ loss: {loss:.6f} -- acc: {train_acc:.2%} -- val_loss: {val_loss:.6f}  -- val_acc: {val_acc:.2%}")
# Out:
# Epoch     1/250 ______ loss: 0.801429 -- acc: 53.45% -- val_loss: 0.776233  -- val_acc: 48.28%
# Epoch     2/250 ______ loss: 0.790294 -- acc: 53.45% -- val_loss: 0.766756  -- val_acc: 48.28%
# Epoch     3/250 ______ loss: 0.780211 -- acc: 54.31% -- val_loss: 0.758210  -- val_acc: 48.28%
# Epoch     4/250 ______ loss: 0.771101 -- acc: 55.17% -- val_loss: 0.750521  -- val_acc: 48.28%
# Epoch     5/250 ______ loss: 0.762887 -- acc: 55.17% -- val_loss: 0.743617  -- val_acc: 48.28%
# Epoch     6/250 ______ loss: 0.755496 -- acc: 54.31% -- val_loss: 0.737430  -- val_acc: 48.28%
# Epoch     7/250 ______ loss: 0.748856 -- acc: 55.17% -- val_loss: 0.731894  -- val_acc: 48.28%
# Epoch     8/250 ______ loss: 0.742901 -- acc: 55.17% -- val_loss: 0.726948  -- val_acc: 48.28%
# Epoch     9/250 ______ loss: 0.737567 -- acc: 55.17% -- val_loss: 0.722536  -- val_acc: 48.28%
# Epoch    10/250 ______ loss: 0.732795 -- acc: 55.17% -- val_loss: 0.718605  -- val_acc: 48.28%
# Epoch    11/250 ______ loss: 0.728530 -- acc: 55.17% -- val_loss: 0.715106  -- val_acc: 48.28%
# Epoch    12/250 ______ loss: 0.724722 -- acc: 55.17% -- val_loss: 0.711995  -- val_acc: 48.28%
# Epoch    13/250 ______ loss: 0.721324 -- acc: 55.17% -- val_loss: 0.709230  -- val_acc: 48.28%
# Epoch    14/250 ______ loss: 0.718292 -- acc: 55.17% -- val_loss: 0.706774  -- val_acc: 51.72%
# Epoch    15/250 ______ loss: 0.715589 -- acc: 55.17% -- val_loss: 0.704594  -- val_acc: 48.28%
# Epoch    16/250 ______ loss: 0.713180 -- acc: 55.17% -- val_loss: 0.702660  -- val_acc: 48.28%
# Epoch    17/250 ______ loss: 0.711031 -- acc: 55.17% -- val_loss: 0.700944  -- val_acc: 48.28%
# Epoch    18/250 ______ loss: 0.709115 -- acc: 55.17% -- val_loss: 0.699421  -- val_acc: 48.28%
# Epoch    19/250 ______ loss: 0.707405 -- acc: 55.17% -- val_loss: 0.698070  -- val_acc: 48.28%
# Epoch    20/250 ______ loss: 0.705879 -- acc: 54.31% -- val_loss: 0.696871  -- val_acc: 48.28%
# Epoch    21/250 ______ loss: 0.704516 -- acc: 55.17% -- val_loss: 0.695806  -- val_acc: 48.28%
# Epoch    22/250 ______ loss: 0.703297 -- acc: 53.45% -- val_loss: 0.694859  -- val_acc: 48.28%
# Epoch    23/250 ______ loss: 0.702206 -- acc: 53.45% -- val_loss: 0.694018  -- val_acc: 51.72%
# Epoch    24/250 ______ loss: 0.701228 -- acc: 55.17% -- val_loss: 0.693269  -- val_acc: 51.72%
# Epoch    25/250 ______ loss: 0.700349 -- acc: 54.31% -- val_loss: 0.692601  -- val_acc: 55.17%
# Epoch    26/250 ______ loss: 0.699559 -- acc: 54.31% -- val_loss: 0.692005  -- val_acc: 55.17%
# Epoch    27/250 ______ loss: 0.698848 -- acc: 55.17% -- val_loss: 0.691473  -- val_acc: 55.17%
# Epoch    28/250 ______ loss: 0.698205 -- acc: 56.03% -- val_loss: 0.690996  -- val_acc: 55.17%
# Epoch    29/250 ______ loss: 0.697623 -- acc: 56.03% -- val_loss: 0.690569  -- val_acc: 55.17%
# Epoch    30/250 ______ loss: 0.697094 -- acc: 56.03% -- val_loss: 0.690184  -- val_acc: 51.72%
# Epoch    31/250 ______ loss: 0.696613 -- acc: 56.03% -- val_loss: 0.689838  -- val_acc: 51.72%
# Epoch    32/250 ______ loss: 0.696174 -- acc: 56.03% -- val_loss: 0.689525  -- val_acc: 51.72%
# Epoch    33/250 ______ loss: 0.695772 -- acc: 57.76% -- val_loss: 0.689241  -- val_acc: 55.17%
# Epoch    34/250 ______ loss: 0.695402 -- acc: 57.76% -- val_loss: 0.688983  -- val_acc: 55.17%
# Epoch    35/250 ______ loss: 0.695062 -- acc: 56.90% -- val_loss: 0.688748  -- val_acc: 58.62%
# Epoch    36/250 ______ loss: 0.694746 -- acc: 56.90% -- val_loss: 0.688533  -- val_acc: 58.62%
# Epoch    37/250 ______ loss: 0.694453 -- acc: 56.90% -- val_loss: 0.688336  -- val_acc: 58.62%
# Epoch    38/250 ______ loss: 0.694180 -- acc: 56.90% -- val_loss: 0.688153  -- val_acc: 58.62%
# Epoch    39/250 ______ loss: 0.693925 -- acc: 56.03% -- val_loss: 0.687985  -- val_acc: 58.62%
# Epoch    40/250 ______ loss: 0.693685 -- acc: 55.17% -- val_loss: 0.687828  -- val_acc: 55.17%
# Epoch    41/250 ______ loss: 0.693459 -- acc: 55.17% -- val_loss: 0.687682  -- val_acc: 55.17%
# Epoch    42/250 ______ loss: 0.693245 -- acc: 55.17% -- val_loss: 0.687545  -- val_acc: 55.17%
# Epoch    43/250 ______ loss: 0.693041 -- acc: 55.17% -- val_loss: 0.687417  -- val_acc: 55.17%
# Epoch    44/250 ______ loss: 0.692848 -- acc: 56.03% -- val_loss: 0.687295  -- val_acc: 55.17%
# Epoch    45/250 ______ loss: 0.692663 -- acc: 56.03% -- val_loss: 0.687180  -- val_acc: 55.17%
# Epoch    46/250 ______ loss: 0.692485 -- acc: 56.90% -- val_loss: 0.687071  -- val_acc: 55.17%
# Epoch    47/250 ______ loss: 0.692314 -- acc: 56.90% -- val_loss: 0.686966  -- val_acc: 55.17%
# Epoch    48/250 ______ loss: 0.692149 -- acc: 56.90% -- val_loss: 0.686866  -- val_acc: 55.17%
# Epoch    49/250 ______ loss: 0.691990 -- acc: 56.90% -- val_loss: 0.686770  -- val_acc: 55.17%
# Epoch    50/250 ______ loss: 0.691835 -- acc: 56.90% -- val_loss: 0.686678  -- val_acc: 55.17%
# Epoch    51/250 ______ loss: 0.691685 -- acc: 56.90% -- val_loss: 0.686588  -- val_acc: 55.17%
# Epoch    52/250 ______ loss: 0.691539 -- acc: 56.90% -- val_loss: 0.686501  -- val_acc: 55.17%
# Epoch    53/250 ______ loss: 0.691396 -- acc: 56.90% -- val_loss: 0.686417  -- val_acc: 55.17%
# Epoch    54/250 ______ loss: 0.691256 -- acc: 56.90% -- val_loss: 0.686335  -- val_acc: 55.17%
# Epoch    55/250 ______ loss: 0.691119 -- acc: 56.90% -- val_loss: 0.686255  -- val_acc: 55.17%
# Epoch    56/250 ______ loss: 0.690985 -- acc: 56.90% -- val_loss: 0.686176  -- val_acc: 55.17%
# Epoch    57/250 ______ loss: 0.690854 -- acc: 56.90% -- val_loss: 0.686100  -- val_acc: 55.17%
# Epoch    58/250 ______ loss: 0.690724 -- acc: 56.90% -- val_loss: 0.686024  -- val_acc: 55.17%
# Epoch    59/250 ______ loss: 0.690597 -- acc: 56.90% -- val_loss: 0.685950  -- val_acc: 51.72%
# Epoch    60/250 ______ loss: 0.690471 -- acc: 56.90% -- val_loss: 0.685878  -- val_acc: 51.72%
# Epoch    61/250 ______ loss: 0.690347 -- acc: 56.90% -- val_loss: 0.685806  -- val_acc: 51.72%
# Epoch    62/250 ______ loss: 0.690225 -- acc: 56.90% -- val_loss: 0.685736  -- val_acc: 51.72%
# Epoch    63/250 ______ loss: 0.690104 -- acc: 56.90% -- val_loss: 0.685666  -- val_acc: 51.72%
# Epoch    64/250 ______ loss: 0.689985 -- acc: 56.90% -- val_loss: 0.685598  -- val_acc: 51.72%
# Epoch    65/250 ______ loss: 0.689867 -- acc: 56.90% -- val_loss: 0.685530  -- val_acc: 51.72%
# Epoch    66/250 ______ loss: 0.689750 -- acc: 56.90% -- val_loss: 0.685463  -- val_acc: 51.72%
# Epoch    67/250 ______ loss: 0.689634 -- acc: 56.90% -- val_loss: 0.685397  -- val_acc: 51.72%
# Epoch    68/250 ______ loss: 0.689520 -- acc: 56.90% -- val_loss: 0.685332  -- val_acc: 51.72%
# Epoch    69/250 ______ loss: 0.689406 -- acc: 56.90% -- val_loss: 0.685267  -- val_acc: 51.72%
# Epoch    70/250 ______ loss: 0.689294 -- acc: 56.90% -- val_loss: 0.685203  -- val_acc: 51.72%
# Epoch    71/250 ______ loss: 0.689183 -- acc: 56.90% -- val_loss: 0.685139  -- val_acc: 51.72%
# Epoch    72/250 ______ loss: 0.689072 -- acc: 56.03% -- val_loss: 0.685076  -- val_acc: 51.72%
# Epoch    73/250 ______ loss: 0.688962 -- acc: 56.03% -- val_loss: 0.685014  -- val_acc: 51.72%
# Epoch    74/250 ______ loss: 0.688854 -- acc: 56.03% -- val_loss: 0.684952  -- val_acc: 51.72%
# Epoch    75/250 ______ loss: 0.688746 -- acc: 56.03% -- val_loss: 0.684891  -- val_acc: 51.72%
# Epoch    76/250 ______ loss: 0.688639 -- acc: 56.03% -- val_loss: 0.684830  -- val_acc: 51.72%
# Epoch    77/250 ______ loss: 0.688533 -- acc: 56.03% -- val_loss: 0.684770  -- val_acc: 51.72%
# Epoch    78/250 ______ loss: 0.688427 -- acc: 56.03% -- val_loss: 0.684710  -- val_acc: 51.72%
# Epoch    79/250 ______ loss: 0.688322 -- acc: 56.03% -- val_loss: 0.684651  -- val_acc: 51.72%
# Epoch    80/250 ______ loss: 0.688218 -- acc: 56.03% -- val_loss: 0.684592  -- val_acc: 51.72%
# Epoch    81/250 ______ loss: 0.688115 -- acc: 56.03% -- val_loss: 0.684534  -- val_acc: 51.72%
# Epoch    82/250 ______ loss: 0.688013 -- acc: 56.03% -- val_loss: 0.684476  -- val_acc: 51.72%
# Epoch    83/250 ______ loss: 0.687911 -- acc: 56.90% -- val_loss: 0.684418  -- val_acc: 51.72%
# Epoch    84/250 ______ loss: 0.687810 -- acc: 56.90% -- val_loss: 0.684361  -- val_acc: 51.72%
# Epoch    85/250 ______ loss: 0.687709 -- acc: 56.90% -- val_loss: 0.684305  -- val_acc: 51.72%
# Epoch    86/250 ______ loss: 0.687610 -- acc: 56.90% -- val_loss: 0.684249  -- val_acc: 51.72%
# Epoch    87/250 ______ loss: 0.687510 -- acc: 56.90% -- val_loss: 0.684193  -- val_acc: 51.72%
# Epoch    88/250 ______ loss: 0.687412 -- acc: 56.90% -- val_loss: 0.684138  -- val_acc: 51.72%
# Epoch    89/250 ______ loss: 0.687314 -- acc: 56.90% -- val_loss: 0.684083  -- val_acc: 51.72%
# Epoch    90/250 ______ loss: 0.687217 -- acc: 56.90% -- val_loss: 0.684029  -- val_acc: 51.72%
# Epoch    91/250 ______ loss: 0.687120 -- acc: 56.90% -- val_loss: 0.683975  -- val_acc: 51.72%
# Epoch    92/250 ______ loss: 0.687024 -- acc: 56.90% -- val_loss: 0.683921  -- val_acc: 51.72%
# Epoch    93/250 ______ loss: 0.686929 -- acc: 56.03% -- val_loss: 0.683868  -- val_acc: 51.72%
# Epoch    94/250 ______ loss: 0.686834 -- acc: 56.03% -- val_loss: 0.683815  -- val_acc: 51.72%
# Epoch    95/250 ______ loss: 0.686740 -- acc: 56.90% -- val_loss: 0.683763  -- val_acc: 51.72%
# Epoch    96/250 ______ loss: 0.686647 -- acc: 56.90% -- val_loss: 0.683711  -- val_acc: 51.72%
# Epoch    97/250 ______ loss: 0.686554 -- acc: 56.90% -- val_loss: 0.683659  -- val_acc: 48.28%
# Epoch    98/250 ______ loss: 0.686461 -- acc: 56.90% -- val_loss: 0.683608  -- val_acc: 48.28%
# Epoch    99/250 ______ loss: 0.686369 -- acc: 56.90% -- val_loss: 0.683557  -- val_acc: 48.28%
# Epoch   100/250 ______ loss: 0.686278 -- acc: 57.76% -- val_loss: 0.683507  -- val_acc: 48.28%
# Epoch   101/250 ______ loss: 0.686187 -- acc: 57.76% -- val_loss: 0.683457  -- val_acc: 48.28%
# Epoch   102/250 ______ loss: 0.686097 -- acc: 57.76% -- val_loss: 0.683407  -- val_acc: 48.28%
# Epoch   103/250 ______ loss: 0.686008 -- acc: 57.76% -- val_loss: 0.683358  -- val_acc: 48.28%
# Epoch   104/250 ______ loss: 0.685919 -- acc: 57.76% -- val_loss: 0.683309  -- val_acc: 48.28%
# Epoch   105/250 ______ loss: 0.685830 -- acc: 57.76% -- val_loss: 0.683260  -- val_acc: 48.28%
# Epoch   106/250 ______ loss: 0.685742 -- acc: 57.76% -- val_loss: 0.683212  -- val_acc: 48.28%
# Epoch   107/250 ______ loss: 0.685654 -- acc: 57.76% -- val_loss: 0.683164  -- val_acc: 48.28%
# Epoch   108/250 ______ loss: 0.685567 -- acc: 57.76% -- val_loss: 0.683116  -- val_acc: 48.28%
# Epoch   109/250 ______ loss: 0.685481 -- acc: 57.76% -- val_loss: 0.683069  -- val_acc: 48.28%
# Epoch   110/250 ______ loss: 0.685395 -- acc: 57.76% -- val_loss: 0.683022  -- val_acc: 48.28%
# Epoch   111/250 ______ loss: 0.685310 -- acc: 56.90% -- val_loss: 0.682976  -- val_acc: 48.28%
# Epoch   112/250 ______ loss: 0.685225 -- acc: 56.90% -- val_loss: 0.682929  -- val_acc: 48.28%
# Epoch   113/250 ______ loss: 0.685140 -- acc: 56.90% -- val_loss: 0.682883  -- val_acc: 48.28%
# Epoch   114/250 ______ loss: 0.685056 -- acc: 56.90% -- val_loss: 0.682838  -- val_acc: 48.28%
# Epoch   115/250 ______ loss: 0.684973 -- acc: 56.90% -- val_loss: 0.682793  -- val_acc: 48.28%
# Epoch   116/250 ______ loss: 0.684890 -- acc: 56.90% -- val_loss: 0.682748  -- val_acc: 48.28%
# Epoch   117/250 ______ loss: 0.684807 -- acc: 56.90% -- val_loss: 0.682703  -- val_acc: 48.28%
# Epoch   118/250 ______ loss: 0.684725 -- acc: 56.90% -- val_loss: 0.682659  -- val_acc: 48.28%
# Epoch   119/250 ______ loss: 0.684644 -- acc: 56.90% -- val_loss: 0.682615  -- val_acc: 48.28%
# Epoch   120/250 ______ loss: 0.684563 -- acc: 56.90% -- val_loss: 0.682571  -- val_acc: 48.28%
# Epoch   121/250 ______ loss: 0.684482 -- acc: 56.90% -- val_loss: 0.682528  -- val_acc: 51.72%
# Epoch   122/250 ______ loss: 0.684402 -- acc: 56.90% -- val_loss: 0.682485  -- val_acc: 51.72%
# Epoch   123/250 ______ loss: 0.684322 -- acc: 56.90% -- val_loss: 0.682442  -- val_acc: 51.72%
# Epoch   124/250 ______ loss: 0.684243 -- acc: 56.90% -- val_loss: 0.682399  -- val_acc: 51.72%
# Epoch   125/250 ______ loss: 0.684164 -- acc: 56.90% -- val_loss: 0.682357  -- val_acc: 51.72%
# Epoch   126/250 ______ loss: 0.684086 -- acc: 57.76% -- val_loss: 0.682315  -- val_acc: 51.72%
# Epoch   127/250 ______ loss: 0.684008 -- acc: 57.76% -- val_loss: 0.682274  -- val_acc: 51.72%
# Epoch   128/250 ______ loss: 0.683930 -- acc: 57.76% -- val_loss: 0.682232  -- val_acc: 51.72%
# Epoch   129/250 ______ loss: 0.683853 -- acc: 57.76% -- val_loss: 0.682191  -- val_acc: 51.72%
# Epoch   130/250 ______ loss: 0.683776 -- acc: 57.76% -- val_loss: 0.682151  -- val_acc: 51.72%
# Epoch   131/250 ______ loss: 0.683700 -- acc: 57.76% -- val_loss: 0.682110  -- val_acc: 51.72%
# Epoch   132/250 ______ loss: 0.683624 -- acc: 57.76% -- val_loss: 0.682070  -- val_acc: 51.72%
# Epoch   133/250 ______ loss: 0.683549 -- acc: 58.62% -- val_loss: 0.682030  -- val_acc: 51.72%
# Epoch   134/250 ______ loss: 0.683474 -- acc: 58.62% -- val_loss: 0.681990  -- val_acc: 51.72%
# Epoch   135/250 ______ loss: 0.683399 -- acc: 58.62% -- val_loss: 0.681951  -- val_acc: 51.72%
# Epoch   136/250 ______ loss: 0.683325 -- acc: 58.62% -- val_loss: 0.681912  -- val_acc: 51.72%
# Epoch   137/250 ______ loss: 0.683251 -- acc: 58.62% -- val_loss: 0.681873  -- val_acc: 51.72%
# Epoch   138/250 ______ loss: 0.683178 -- acc: 58.62% -- val_loss: 0.681834  -- val_acc: 51.72%
# Epoch   139/250 ______ loss: 0.683105 -- acc: 58.62% -- val_loss: 0.681796  -- val_acc: 51.72%
# Epoch   140/250 ______ loss: 0.683032 -- acc: 58.62% -- val_loss: 0.681758  -- val_acc: 51.72%
# Epoch   141/250 ______ loss: 0.682960 -- acc: 58.62% -- val_loss: 0.681720  -- val_acc: 51.72%
# Epoch   142/250 ______ loss: 0.682888 -- acc: 58.62% -- val_loss: 0.681682  -- val_acc: 51.72%
# Epoch   143/250 ______ loss: 0.682817 -- acc: 58.62% -- val_loss: 0.681645  -- val_acc: 51.72%
# Epoch   144/250 ______ loss: 0.682746 -- acc: 58.62% -- val_loss: 0.681608  -- val_acc: 51.72%
# Epoch   145/250 ______ loss: 0.682675 -- acc: 58.62% -- val_loss: 0.681571  -- val_acc: 51.72%
# Epoch   146/250 ______ loss: 0.682605 -- acc: 58.62% -- val_loss: 0.681534  -- val_acc: 51.72%
# Epoch   147/250 ______ loss: 0.682535 -- acc: 58.62% -- val_loss: 0.681498  -- val_acc: 51.72%
# Epoch   148/250 ______ loss: 0.682465 -- acc: 58.62% -- val_loss: 0.681462  -- val_acc: 51.72%
# Epoch   149/250 ______ loss: 0.682396 -- acc: 58.62% -- val_loss: 0.681426  -- val_acc: 51.72%
# Epoch   150/250 ______ loss: 0.682327 -- acc: 58.62% -- val_loss: 0.681390  -- val_acc: 51.72%
# Epoch   151/250 ______ loss: 0.682258 -- acc: 58.62% -- val_loss: 0.681355  -- val_acc: 51.72%
# Epoch   152/250 ______ loss: 0.682190 -- acc: 58.62% -- val_loss: 0.681320  -- val_acc: 55.17%
# Epoch   153/250 ______ loss: 0.682122 -- acc: 58.62% -- val_loss: 0.681285  -- val_acc: 55.17%
# Epoch   154/250 ______ loss: 0.682055 -- acc: 58.62% -- val_loss: 0.681250  -- val_acc: 55.17%
# Epoch   155/250 ______ loss: 0.681987 -- acc: 58.62% -- val_loss: 0.681215  -- val_acc: 55.17%
# Epoch   156/250 ______ loss: 0.681921 -- acc: 57.76% -- val_loss: 0.681181  -- val_acc: 55.17%
# Epoch   157/250 ______ loss: 0.681854 -- acc: 56.90% -- val_loss: 0.681147  -- val_acc: 55.17%
# Epoch   158/250 ______ loss: 0.681788 -- acc: 57.76% -- val_loss: 0.681113  -- val_acc: 55.17%
# Epoch   159/250 ______ loss: 0.681722 -- acc: 57.76% -- val_loss: 0.681079  -- val_acc: 55.17%
# Epoch   160/250 ______ loss: 0.681657 -- acc: 57.76% -- val_loss: 0.681045  -- val_acc: 55.17%
# Epoch   161/250 ______ loss: 0.681591 -- acc: 57.76% -- val_loss: 0.681012  -- val_acc: 55.17%
# Epoch   162/250 ______ loss: 0.681526 -- acc: 57.76% -- val_loss: 0.680979  -- val_acc: 55.17%
# Epoch   163/250 ______ loss: 0.681462 -- acc: 57.76% -- val_loss: 0.680946  -- val_acc: 55.17%
# Epoch   164/250 ______ loss: 0.681398 -- acc: 57.76% -- val_loss: 0.680913  -- val_acc: 55.17%
# Epoch   165/250 ______ loss: 0.681334 -- acc: 57.76% -- val_loss: 0.680881  -- val_acc: 55.17%
# Epoch   166/250 ______ loss: 0.681270 -- acc: 57.76% -- val_loss: 0.680848  -- val_acc: 55.17%
# Epoch   167/250 ______ loss: 0.681207 -- acc: 57.76% -- val_loss: 0.680816  -- val_acc: 55.17%
# Epoch   168/250 ______ loss: 0.681144 -- acc: 57.76% -- val_loss: 0.680784  -- val_acc: 55.17%
# Epoch   169/250 ______ loss: 0.681081 -- acc: 57.76% -- val_loss: 0.680752  -- val_acc: 55.17%
# Epoch   170/250 ______ loss: 0.681019 -- acc: 57.76% -- val_loss: 0.680721  -- val_acc: 55.17%
# Epoch   171/250 ______ loss: 0.680957 -- acc: 57.76% -- val_loss: 0.680689  -- val_acc: 55.17%
# Epoch   172/250 ______ loss: 0.680895 -- acc: 57.76% -- val_loss: 0.680658  -- val_acc: 55.17%
# Epoch   173/250 ______ loss: 0.680833 -- acc: 57.76% -- val_loss: 0.680627  -- val_acc: 55.17%
# Epoch   174/250 ______ loss: 0.680772 -- acc: 57.76% -- val_loss: 0.680596  -- val_acc: 55.17%
# Epoch   175/250 ______ loss: 0.680711 -- acc: 57.76% -- val_loss: 0.680566  -- val_acc: 55.17%
# Epoch   176/250 ______ loss: 0.680650 -- acc: 56.90% -- val_loss: 0.680535  -- val_acc: 55.17%
# Epoch   177/250 ______ loss: 0.680590 -- acc: 56.90% -- val_loss: 0.680505  -- val_acc: 55.17%
# Epoch   178/250 ______ loss: 0.680530 -- acc: 56.90% -- val_loss: 0.680475  -- val_acc: 55.17%
# Epoch   179/250 ______ loss: 0.680470 -- acc: 57.76% -- val_loss: 0.680445  -- val_acc: 55.17%
# Epoch   180/250 ______ loss: 0.680410 -- acc: 57.76% -- val_loss: 0.680415  -- val_acc: 55.17%
# Epoch   181/250 ______ loss: 0.680351 -- acc: 57.76% -- val_loss: 0.680385  -- val_acc: 55.17%
# Epoch   182/250 ______ loss: 0.680292 -- acc: 57.76% -- val_loss: 0.680356  -- val_acc: 55.17%
# Epoch   183/250 ______ loss: 0.680233 -- acc: 57.76% -- val_loss: 0.680326  -- val_acc: 55.17%
# Epoch   184/250 ______ loss: 0.680175 -- acc: 57.76% -- val_loss: 0.680297  -- val_acc: 55.17%
# Epoch   185/250 ______ loss: 0.680117 -- acc: 57.76% -- val_loss: 0.680268  -- val_acc: 55.17%
# Epoch   186/250 ______ loss: 0.680059 -- acc: 57.76% -- val_loss: 0.680239  -- val_acc: 55.17%
# Epoch   187/250 ______ loss: 0.680001 -- acc: 57.76% -- val_loss: 0.680211  -- val_acc: 55.17%
# Epoch   188/250 ______ loss: 0.679944 -- acc: 57.76% -- val_loss: 0.680182  -- val_acc: 55.17%
# Epoch   189/250 ______ loss: 0.679886 -- acc: 57.76% -- val_loss: 0.680154  -- val_acc: 55.17%
# Epoch   190/250 ______ loss: 0.679829 -- acc: 57.76% -- val_loss: 0.680126  -- val_acc: 55.17%
# Epoch   191/250 ______ loss: 0.679773 -- acc: 56.90% -- val_loss: 0.680098  -- val_acc: 55.17%
# Epoch   192/250 ______ loss: 0.679716 -- acc: 56.90% -- val_loss: 0.680070  -- val_acc: 55.17%
# Epoch   193/250 ______ loss: 0.679660 -- acc: 57.76% -- val_loss: 0.680042  -- val_acc: 55.17%
# Epoch   194/250 ______ loss: 0.679604 -- acc: 57.76% -- val_loss: 0.680014  -- val_acc: 55.17%
# Epoch   195/250 ______ loss: 0.679548 -- acc: 57.76% -- val_loss: 0.679987  -- val_acc: 55.17%
# Epoch   196/250 ______ loss: 0.679493 -- acc: 57.76% -- val_loss: 0.679959  -- val_acc: 55.17%
# Epoch   197/250 ______ loss: 0.679438 -- acc: 57.76% -- val_loss: 0.679932  -- val_acc: 55.17%
# Epoch   198/250 ______ loss: 0.679383 -- acc: 57.76% -- val_loss: 0.679905  -- val_acc: 55.17%
# Epoch   199/250 ______ loss: 0.679328 -- acc: 57.76% -- val_loss: 0.679878  -- val_acc: 55.17%
# Epoch   200/250 ______ loss: 0.679273 -- acc: 57.76% -- val_loss: 0.679851  -- val_acc: 55.17%
# Epoch   201/250 ______ loss: 0.679219 -- acc: 57.76% -- val_loss: 0.679825  -- val_acc: 55.17%
# Epoch   202/250 ______ loss: 0.679165 -- acc: 57.76% -- val_loss: 0.679798  -- val_acc: 55.17%
# Epoch   203/250 ______ loss: 0.679111 -- acc: 57.76% -- val_loss: 0.679772  -- val_acc: 55.17%
# Epoch   204/250 ______ loss: 0.679057 -- acc: 57.76% -- val_loss: 0.679746  -- val_acc: 55.17%
# Epoch   205/250 ______ loss: 0.679004 -- acc: 57.76% -- val_loss: 0.679719  -- val_acc: 55.17%
# Epoch   206/250 ______ loss: 0.678951 -- acc: 57.76% -- val_loss: 0.679693  -- val_acc: 55.17%
# Epoch   207/250 ______ loss: 0.678898 -- acc: 57.76% -- val_loss: 0.679668  -- val_acc: 55.17%
# Epoch   208/250 ______ loss: 0.678845 -- acc: 57.76% -- val_loss: 0.679642  -- val_acc: 55.17%
# Epoch   209/250 ______ loss: 0.678793 -- acc: 56.03% -- val_loss: 0.679616  -- val_acc: 55.17%
# Epoch   210/250 ______ loss: 0.678740 -- acc: 56.03% -- val_loss: 0.679591  -- val_acc: 55.17%
# Epoch   211/250 ______ loss: 0.678688 -- acc: 56.03% -- val_loss: 0.679565  -- val_acc: 55.17%
# Epoch   212/250 ______ loss: 0.678636 -- acc: 56.03% -- val_loss: 0.679540  -- val_acc: 55.17%
# Epoch   213/250 ______ loss: 0.678584 -- acc: 56.03% -- val_loss: 0.679515  -- val_acc: 55.17%
# Epoch   214/250 ______ loss: 0.678533 -- acc: 56.03% -- val_loss: 0.679490  -- val_acc: 55.17%
# Epoch   215/250 ______ loss: 0.678482 -- acc: 56.03% -- val_loss: 0.679465  -- val_acc: 55.17%
# Epoch   216/250 ______ loss: 0.678430 -- acc: 56.03% -- val_loss: 0.679440  -- val_acc: 55.17%
# Epoch   217/250 ______ loss: 0.678380 -- acc: 56.03% -- val_loss: 0.679416  -- val_acc: 55.17%
# Epoch   218/250 ______ loss: 0.678329 -- acc: 56.90% -- val_loss: 0.679391  -- val_acc: 55.17%
# Epoch   219/250 ______ loss: 0.678278 -- acc: 56.90% -- val_loss: 0.679367  -- val_acc: 55.17%
# Epoch   220/250 ______ loss: 0.678228 -- acc: 56.90% -- val_loss: 0.679342  -- val_acc: 55.17%
# Epoch   221/250 ______ loss: 0.678178 -- acc: 56.90% -- val_loss: 0.679318  -- val_acc: 55.17%
# Epoch   222/250 ______ loss: 0.678128 -- acc: 56.90% -- val_loss: 0.679294  -- val_acc: 55.17%
# Epoch   223/250 ______ loss: 0.678078 -- acc: 56.90% -- val_loss: 0.679270  -- val_acc: 55.17%
# Epoch   224/250 ______ loss: 0.678029 -- acc: 56.90% -- val_loss: 0.679246  -- val_acc: 55.17%
# Epoch   225/250 ______ loss: 0.677979 -- acc: 56.90% -- val_loss: 0.679222  -- val_acc: 55.17%
# Epoch   226/250 ______ loss: 0.677930 -- acc: 56.90% -- val_loss: 0.679199  -- val_acc: 55.17%
# Epoch   227/250 ______ loss: 0.677881 -- acc: 56.90% -- val_loss: 0.679175  -- val_acc: 55.17%
# Epoch   228/250 ______ loss: 0.677832 -- acc: 56.90% -- val_loss: 0.679152  -- val_acc: 55.17%
# Epoch   229/250 ______ loss: 0.677784 -- acc: 57.76% -- val_loss: 0.679128  -- val_acc: 55.17%
# Epoch   230/250 ______ loss: 0.677735 -- acc: 57.76% -- val_loss: 0.679105  -- val_acc: 55.17%
# Epoch   231/250 ______ loss: 0.677687 -- acc: 57.76% -- val_loss: 0.679082  -- val_acc: 55.17%
# Epoch   232/250 ______ loss: 0.677639 -- acc: 57.76% -- val_loss: 0.679059  -- val_acc: 55.17%
# Epoch   233/250 ______ loss: 0.677591 -- acc: 57.76% -- val_loss: 0.679036  -- val_acc: 55.17%
# Epoch   234/250 ______ loss: 0.677543 -- acc: 58.62% -- val_loss: 0.679013  -- val_acc: 55.17%
# Epoch   235/250 ______ loss: 0.677496 -- acc: 58.62% -- val_loss: 0.678990  -- val_acc: 55.17%
# Epoch   236/250 ______ loss: 0.677448 -- acc: 58.62% -- val_loss: 0.678967  -- val_acc: 55.17%
# Epoch   237/250 ______ loss: 0.677401 -- acc: 58.62% -- val_loss: 0.678945  -- val_acc: 55.17%
# Epoch   238/250 ______ loss: 0.677354 -- acc: 58.62% -- val_loss: 0.678922  -- val_acc: 55.17%
# Epoch   239/250 ______ loss: 0.677307 -- acc: 58.62% -- val_loss: 0.678900  -- val_acc: 55.17%
# Epoch   240/250 ______ loss: 0.677260 -- acc: 58.62% -- val_loss: 0.678878  -- val_acc: 55.17%
# Epoch   241/250 ______ loss: 0.677214 -- acc: 58.62% -- val_loss: 0.678855  -- val_acc: 55.17%
# Epoch   242/250 ______ loss: 0.677167 -- acc: 58.62% -- val_loss: 0.678833  -- val_acc: 55.17%
# Epoch   243/250 ______ loss: 0.677121 -- acc: 58.62% -- val_loss: 0.678811  -- val_acc: 55.17%
# Epoch   244/250 ______ loss: 0.677075 -- acc: 58.62% -- val_loss: 0.678789  -- val_acc: 55.17%
# Epoch   245/250 ______ loss: 0.677029 -- acc: 58.62% -- val_loss: 0.678767  -- val_acc: 55.17%
# Epoch   246/250 ______ loss: 0.676983 -- acc: 58.62% -- val_loss: 0.678746  -- val_acc: 55.17%
# Epoch   247/250 ______ loss: 0.676938 -- acc: 58.62% -- val_loss: 0.678724  -- val_acc: 55.17%
# Epoch   248/250 ______ loss: 0.676892 -- acc: 58.62% -- val_loss: 0.678702  -- val_acc: 55.17%
# Epoch   249/250 ______ loss: 0.676847 -- acc: 58.62% -- val_loss: 0.678681  -- val_acc: 55.17%
# Epoch   250/250 ______ loss: 0.676802 -- acc: 58.62% -- val_loss: 0.678659  -- val_acc: 55.17%

# %%
# ------------- Test -------------
_, test_logits = forward(X_test_n)
test_pred = (test_logits > 0).astype(int)
acc = np.mean(test_pred.flatten() == y_test_bin.flatten())
print(f"\nTest Direction Accuracy: {acc:.2%}")

import pandas as pd
# Create a comparison table
results_df = pd.DataFrame({
    'Actual Value': y_test,
    'Predicted Value': test_logits.flatten(),
    'Direction': (((y_test > 0) & (test_logits.flatten() > 0)) | ((y_test < 0) & (test_logits.flatten() < 0))).astype(int)
})

print("Predictions for the 2024-2025 Test Set:")
display(results_df)
count_ones = results_df['Direction'].value_counts()[1]
print(results_df['Direction'].value_counts())
print(f"Total right direction => {count_ones}, {(count_ones/len(test_logits.flatten()))*100:.2f}%")
# Out:
# Test Direction Accuracy: 63.64%
# Predictions for the 2024-2025 Test Set:
#     Actual Value  Predicted Value  Direction
# 0      -0.017473         0.141581          0
# 1      -0.339443         0.186060          0
# 2       0.031541         0.480487          1
# 3      -0.215161         0.113133          0
# 4      -0.087107         0.155240          0
# 5       0.485383         0.362483          1
# 6      -0.220254        -0.060890          1
# 7       0.307394         0.626604          1
# 8       0.306878         0.201115          1
# 9       0.113420         0.078788          1
# 10      0.198257         0.168988          1
# Direction
# 1    7
# 0    4
# Name: count, dtype: int64
# Total right direction => 7, 63.64%

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'
plt.figure(figsize=(10, 6))
plt.plot(range(len(y_test)), y_test, label="Actual Values", marker="o")
plt.plot(range(len(test_logits)), test_logits.flatten(), label="Predicted Values", marker="x", linestyle="--")
plt.title("Actual vs Predicted Values (2024-2025)")
plt.xlabel("Samples")
plt.ylabel("Target Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


# Extract data from the epoch_log list
# epoch_log contains tuples: (epoch, loss, val_loss, train_acc, val_acc)
epochs_list = [entry[0] for entry in epoch_log]
train_bce_list = [entry[1] for entry in epoch_log]
val_bce_list = [entry[2] for entry in epoch_log]
train_acc_list = [entry[3] for entry in epoch_log]
val_acc_list = [entry[4] for entry in epoch_log]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Subplot 1: BCE Loss
ax1.plot(epochs_list, train_bce_list, label='Training Loss')
ax1.plot(epochs_list, val_bce_list, label='Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss (BCE)')
ax1.set_title('Training vs Validation Loss')
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.7)

# Subplot 2: Accuracy
ax2.plot(epochs_list, train_acc_list, label='Training Accuracy')
ax2.plot(epochs_list, val_acc_list, label='Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_title('Training vs Validation Accuracy')
ax2.legend()
ax2.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
